# %% [markdown]
# # **EDA for Predictive Healthcare Diagnostics**

# %% [markdown]
# ### **Context:**
# This synthetic healthcare dataset has been created to serve as a valuable resource for data science, machine learning, and data analysis enthusiasts. It is designed to mimic real-world healthcare data, enabling users to practice, develop, and showcase their data manipulation and analysis skills in the context of the healthcare industry.

# %% [markdown]
# ### **Data Collection**
# - **Dataset Source** - https://www.kaggle.com/datasets/prasad22/healthcare-dataset/data
# - The data consists of 5550 rows and 15 columns

# %% [markdown]
# ### **Dataset Information:**
# Each column provides specific information about the patient, their admission, and the healthcare services provided, making this dataset suitable for various data analysis and modeling tasks in the healthcare domain. Here's a brief explanation of each column in the dataset -
#
# - **Name:** This column represents the name of the patient associated with the healthcare record.
# - **Age:** The age of the patient at the time of admission, expressed in years.
# - **Gender:** Indicates the gender of the patient, either "Male" or "Female."
# - **Blood Type:** The patient's blood type, which can be one of the common blood types (e.g., "A+", "O-", etc.).
# - **Medical Condition:** This column specifies the primary medical condition or diagnosis associated with the patient, such as "Diabetes," "Hypertension," "Asthma," and more.
# - **Date of Admission:** The date on which the patient was admitted to the healthcare facility.
# - **Doctor:** The name of the doctor responsible for the patient's care during their admission.
# - **Hospital:** Identifies the healthcare facility or hospital where the patient was admitted.
# - **Insurance Provider:** This column indicates the patient's insurance provider, which can be one of several options, including "Aetna," "Blue Cross," "Cigna," "UnitedHealthcare," and "Medicare."
# - **Billing Amount:** The amount of money billed for the patient's healthcare services during their admission. This is expressed as a floating-point number.
# - Room Number:** The room number where the patient was accommodated during their admission.
# - **Admission Type:** Specifies the type of admission, which can be "Emergency," "Elective," or "Urgent," reflecting the circumstances of the admission.
# - **Discharge Date:** The date on which the patient was discharged from the healthcare facility, based on the admission date and a random number of days within a realistic range.
# - **Medication:** Identifies a medication prescribed or administered to the patient during their admission. Examples include "Aspirin," "Ibuprofen," "Penicillin," "Paracetamol," and "Lipitor."
# - **Test Results:** Describes the results of a medical test conducted during the patient's admission. Possible values include "Normal," "Abnormal," or "Inconclusive," indicating the outcome of the test.

# %% [markdown]
# ### Import required libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read the CSV File

# %%
df = pd.read_csv("healthcare_dataset.csv")
# Read the first five rows of the dataset
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %% [markdown]
# ### Shape and columns of the data

# %%
shape = df.shape
print("Shape of the data:",shape)
print("\n")
columns= df.columns
print("Columns of the data:",columns)
# Out:
# Shape of the data: (55500, 15)
#
#
# Columns of the data: Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %% [markdown]
# - There are 55500 rows and 15 columns in the dataset

# %% [markdown]
# ### Informantion about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %% [markdown]
# - There are no missing values present in the dataset
# - Let's remove a few columns like **Name, Date of Admission, Date of Admission, Discharge Date, Room Number, Billimg Amount** columns as it is not helpful in training the model.
# - **Test results** is the **Target column**.

# %% [markdown]
# ### Check for missing values

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %% [markdown]
# - No missing values present in the dataset

# %% [markdown]
# ### Removing unwanted columns (Name, Date of Admission, Discharge Date, Room Number, Billing Amount) as these columns add no value while training the model

# %%
df1=df.drop(columns=["Name","Date of Admission", "Discharge Date", "Room Number", "Billing Amount"],index=None)

# %%
df1.head()
# Out:
#    Age  Gender Blood Type Medical Condition            Doctor  \
# 0   30    Male         B-            Cancer     Matthew Smith
# 1   62    Male         A+           Obesity   Samantha Davies
# 2   76  Female         A-           Obesity  Tiffany Mitchell
# 3   28  Female         O+          Diabetes       Kevin Wells
# 4   43  Female        AB+            Cancer    Kathleen Hanna
#
#                      Hospital Insurance Provider Admission Type   Medication  \
# 0             Sons and Miller         Blue Cross         Urgent  Paracetamol
# 1                     Kim Inc           Medicare      Emergency    Ibuprofen
# 2                    Cook PLC              Aetna      Emergency      Aspirin
# 3  Hernandez Rogers and Vang,           Medicare       Elective    Ibuprofen
# 4                 White-White              Aetna         Urgent   Penicillin
#
#    Test Results
# 0        Normal
# 1  Inconclusive
# 2        Normal
# 3      Abnormal
# 4      Abnormal

# %% [markdown]
# ### Recheck the shape of the data

# %%
df1.shape
# Out:
# (55500, 10)

# %% [markdown]
# ### Re-checking the information about the dataset

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 55500 non-null  int64
#  1   Gender              55500 non-null  object
#  2   Blood Type          55500 non-null  object
#  3   Medical Condition   55500 non-null  object
#  4   Doctor              55500 non-null  object
#  5   Hospital            55500 non-null  object
#  6   Insurance Provider  55500 non-null  object
#  7   Admission Type      55500 non-null  object
#  8   Medication          55500 non-null  object
#  9   Test Results        55500 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 4.2+ MB

# %% [markdown]
# - There are only 10 columns that are remaining.

# %% [markdown]
# ### Check for duplicates

# %%
duplicates=df1.duplicated().sum()
if duplicates==0:
    print("There are no duplicate values present in the dataset")
else:
    print(f"There are {duplicates} duplicate values present in the dataset")
# Out:
# There are 534 duplicate values present in the dataset

# %% [markdown]
# - The dataset will definitely have duplicates, as most of the column values are repeated.

# %% [markdown]
# ### Unique values of different columns

# %%
age= df1["Age"].unique()
print("Unique values in Age column:",age)
print("\n")
gender= df1["Gender"].unique()
print("Unique values in Gender column:",gender)
print("\n")
blood_type= df1["Blood Type"].unique()
print("Unique values in Blood Type column:",blood_type)
print("\n")
condition= df1["Medical Condition"].unique()
print("Unique values in Medical Condition column:",condition)
print("\n")
doctor= df1["Doctor"].unique()
print("Unique values in Doctor column:",doctor)
print("\n")
hospital= df1["Hospital"].unique()
print("Unique values in Hospital column:",hospital)
print("\n")
insurance= df1["Insurance Provider"].unique()
print("Unique values in Insurance Provider column:",insurance)
print("\n")
admission= df1["Admission Type"].unique()
print("Unique values in Admission Type column:",admission)
print("\n")
medication= df1["Medication"].unique()
print("Unique values in Medication column:",medication)
print("\n")
results= df1["Test Results"].unique()
print("Unique values in Test Results column:",results)
# Out:
# Unique values in Age column: [30 62 76 28 43 36 21 20 82 58 72 38 75 68 44 46 63 34 67 48 59 73 51 23
#  78 25 33 26 70 57 74 81 49 65 31 22 77 42 24 84 55 40 83 18 27 19 29 61
#  80 60 35 79 53 69 47 85 52 37 50 32 54 45 66 39 56 64 71 41 88 17 87 86
#  15 16 13 14 89]
#
#
# Unique values in Gender column: ['Male' 'Female']
#
#
# Unique values in Blood Type column: ['B-' 'A+' 'A-' 'O+' 'AB+' 'AB-' 'B+' 'O-']
#
#
# Unique values in Medical Condition column: ['Cancer' 'Obesity' 'Diabetes' 'Asthma' 'Hypertension' 'Arthritis']
#
#
# Unique values in Doctor column: ['Matthew Smith' 'Samantha Davies' 'Tiffany Mitchell' ... 'Deborah Sutton'
#  'Mary Bartlett' 'Alec May']
#
#
# Unique values in Hospital column: ['Sons and Miller' 'Kim Inc' 'Cook PLC' ... 'Guzman Jones and Graves,'
#  'and Williams, Brown Mckenzie' 'Moreno Murphy, Griffith and']
#
#
# Unique values in Insurance Provider column: ['Blue Cross' 'Medicare' 'Aetna' 'UnitedHealthcare' 'Cigna']
#
#
# ...

# %% [markdown]
# ### Statistical summary

# %%
df1.describe()
# Out:
#                 Age
# count  55500.000000
# mean      51.539459
# std       19.602454
# min       13.000000
# 25%       35.000000
# 50%       52.000000
# 75%       68.000000
# max       89.000000

# %% [markdown]
# - Here we have only one column as a numarical value.
# - We have to convert all the categorical features to numerical values later on before training the model.

# %% [markdown]
# ### **Univarient Analysis**

# %% [markdown]
# ### **EDA**

# %% [markdown]
# ### Countplot

# %% [markdown]
# ### i. Gender column

# %%
plt.figure(figsize=(8,8))
sns.countplot(x=df1['Gender'])
plt.title("Countplot for Gender column")
plt.show()

# value_counts
df1['Gender'].value_counts()
# Out:
# Gender
# Male      27774
# Female    27726
# Name: count, dtype: int64

# %% [markdown]
# #### Observation:
# - The graph shows that there are more Male patients(27,774), than Female patients(27,726).)

# %% [markdown]
# ### ii. Blood Type column

# %%
plt.figure(figsize=(8,8))
sns.countplot(x=df1['Blood Type'])
plt.title("Countplot for Blood Type column")
plt.show()

# value_counts
df1['Blood Type'].value_counts()
# Out:
# Blood Type
# A-     6969
# A+     6956
# AB+    6947
# AB-    6945
# B+     6945
# B-     6944
# O+     6917
# O-     6877
# Name: count, dtype: int64

# %% [markdown]
# #### Observation:
# - 6,969 patients have A- blood type (1st place)
# - 6,956 patients have A+ blood type (2nd place)
# - 6,947 patients have AB+ blood type (3rd place)
# - 6,945 patients have AB- blood type (4th place)
# - 6,945 patients have B+ blood type (4th place)
# - 6,944 patients have B- blood type (5th place)
# - 6,917 patients have O+ blood type (6th place)
# - 6,877 patients have O- blood type (7h place)

# %% [markdown]
# ### iii. Medical Condition column

# %%
plt.figure(figsize=(8,8))
sns.countplot(x=df1['Medical Condition'])
plt.title("Countplot for Medical Condition column")
plt.show()

# value_counts
df1['Medical Condition'].value_counts()
# Out:
# Medical Condition
# Arthritis       9308
# Diabetes        9304
# Hypertension    9245
# Obesity         9231
# Cancer          9227
# Asthma          9185
# Name: count, dtype: int64

# %% [markdown]
# #### Observation:
# - There are 9,308 patients diagnosed with Arthritis.
# - There are  9,304 patients diagnosed with Diabetes.
# - There are 9,245 patients diagnosed with Hypertension.
# - There are 9,231 patients diagnosed with Obesity.
# - There are 9,227 patients diagnosed with Cancer.
# - There are 9,185 patients diagnosed with Asthma.

# %% [markdown]
# ### iv. Insurance Provider column

# %%
plt.figure(figsize=(8,8))
sns.countplot(x=df1['Insurance Provider'])
plt.title("Countplot for Insurance Provider column")
plt.show()

# value_counts
df1['Insurance Provider'].value_counts()
# Out:
# Insurance Provider
# Cigna               11249
# Medicare            11154
# UnitedHealthcare    11125
# Blue Cross          11059
# Aetna               10913
# Name: count, dtype: int64

# %% [markdown]
# #### Observation:
# - Cigna has the most patients (11,249), but the numbers are very close.
# - Medicare, UnitedHealthcare, and Blue Cross each cover around 11,000 patients.
# - Aetna has the lowest count (10,913), but the difference is small.
# - All five providers have a similar number of insured patients.

# %% [markdown]
# ### v. Admission Type column

# %%
plt.figure(figsize=(8,8))
sns.countplot(x=df1['Admission Type'])
plt.title("Countplot for Admission Type column")
plt.show()

df1['Admission Type'].value_counts()
# Out:
# Admission Type
# Elective     18655
# Urgent       18576
# Emergency    18269
# Name: count, dtype: int64

# %% [markdown]
# #### Observation:
# - 18,655 patients have an "Elective" admission type.
# - 18,576 patients have an "Urgent" admission type.
# - 18,269 patients have an "Emergency" admission type.

# %% [markdown]
# ### vi. Medication column

# %%
plt.figure(figsize=(8,8))
sns.countplot(x=df1['Medication'])
plt.title("Countplot for Medication column")
plt.show()

df1['Medication'].value_counts()
# Out:
# Medication
# Lipitor        11140
# Ibuprofen      11127
# Aspirin        11094
# Paracetamol    11071
# Penicillin     11068
# Name: count, dtype: int64

# %% [markdown]
# #### Observation:
# -  11,140 patients consume Lipitor medication.
# -  11,127 patients consume Ibuprofen medication.
# -  11,094 patients consume Asprin medication.
# -  11,071 patients consume Paracetamol medication.
# -  11,068 patients consume Penicillin medication.

# %% [markdown]
# ### vii. Test Results column

# %%
plt.figure(figsize=(8,8))
sns.countplot(x=df1['Test Results'])
plt.title("Countplot for Test Results column")
plt.show()

df1['Test Results'].value_counts()
# Out:
# Test Results
# Abnormal        18627
# Normal          18517
# Inconclusive    18356
# Name: count, dtype: int64

# %% [markdown]
# #### Observation:
# - 18,627 test results have come out to be Abnormal.
# - 18,517 test results have come out to be Normal.
# - 18,356 test results have come out to be Inconclusive.

# %% [markdown]
# ### Multivariate Analysis (Multiple Variables)

# %%
df1.head()
# Out:
#    Age  Gender Blood Type Medical Condition            Doctor  \
# 0   30    Male         B-            Cancer     Matthew Smith
# 1   62    Male         A+           Obesity   Samantha Davies
# 2   76  Female         A-           Obesity  Tiffany Mitchell
# 3   28  Female         O+          Diabetes       Kevin Wells
# 4   43  Female        AB+            Cancer    Kathleen Hanna
#
#                      Hospital Insurance Provider Admission Type   Medication  \
# 0             Sons and Miller         Blue Cross         Urgent  Paracetamol
# 1                     Kim Inc           Medicare      Emergency    Ibuprofen
# 2                    Cook PLC              Aetna      Emergency      Aspirin
# 3  Hernandez Rogers and Vang,           Medicare       Elective    Ibuprofen
# 4                 White-White              Aetna         Urgent   Penicillin
#
#    Test Results
# 0        Normal
# 1  Inconclusive
# 2        Normal
# 3      Abnormal
# 4      Abnormal

# %% [markdown]
# ### Boxplot

# %% [markdown]
# ### Age vs Test Results

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x=df1["Age"],y=df1["Test Results"])
plt.title("Boxplot for Age vs Test Results")
plt.show()

# %% [markdown]
# #### Observation:
# - It looks like there are no outliers present.
# - The data is evenly distributed with no skewness.
# - Q1 falls around 30-40 for all the 3 Test Results categories(Normal, Inconclusive, Abnormal).
# - Q3 falls around 60-70 for all the 3 Test Results categories(Normal, Inconclusive, Abnormal).
# - Median falls around 50-60 for all the 3 Test Results categories(Normal, Inconclusive, Abnormal).

# %% [markdown]
# ### Age vs Gender

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x=df1["Age"],y=df1["Gender"])
plt.title("Boxplot for Age vs Gender")
plt.show()

# %% [markdown]
# #### Observation:
# - It looks like there are no outliers present.
# - The data is evenly distributed with no skewness.
# - Q1 falls around 30-40 for both the Gender.
# - Q3 falls around 60-70 for both the Gender.
# - Median falls around 50-60 for both the Gender.

# %% [markdown]
# ### Age vs Medical Condition

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x=df1["Age"],y=df1["Medical Condition"])
plt.title("Boxplot for Age vs Medical Condition")
plt.show()

# %% [markdown]
# #### Observation:
# - It looks like there are no outliers present.
# - The data is evenly distributed with no skewness.
# - Q1 falls around 30-40 for all the Medical Condition.
# - Q3 falls around 60-70 for all the  Medical Condition
# - Median falls around 50-60 for all the Medical Condition.

# %%
df1.head()
# Out:
#    Age  Gender Blood Type Medical Condition            Doctor  \
# 0   30    Male         B-            Cancer     Matthew Smith
# 1   62    Male         A+           Obesity   Samantha Davies
# 2   76  Female         A-           Obesity  Tiffany Mitchell
# 3   28  Female         O+          Diabetes       Kevin Wells
# 4   43  Female        AB+            Cancer    Kathleen Hanna
#
#                      Hospital Insurance Provider Admission Type   Medication  \
# 0             Sons and Miller         Blue Cross         Urgent  Paracetamol
# 1                     Kim Inc           Medicare      Emergency    Ibuprofen
# 2                    Cook PLC              Aetna      Emergency      Aspirin
# 3  Hernandez Rogers and Vang,           Medicare       Elective    Ibuprofen
# 4                 White-White              Aetna         Urgent   Penicillin
#
#    Test Results
# 0        Normal
# 1  Inconclusive
# 2        Normal
# 3      Abnormal
# 4      Abnormal

# %% [markdown]
# ### Scatterplot

# %%
# Gender vs Test Results
plt.figure(figsize=(8,8))
sns.scatterplot(x=df1["Gender"],y=df1["Test Results"])
plt.title("Scatterplot for Gender vs Test Results")
plt.show()

# Medication vs Test Results
plt.figure(figsize=(8,8))
sns.scatterplot(x=df1["Medication"],y=df1["Test Results"])
plt.title("Scatterplot for Medication vs Test Results")
plt.show()

# Blood Type vs Medical Condtion
plt.figure(figsize=(8,8))
sns.scatterplot(x=df1["Blood Type"],y=df1["Medical Condition"])
plt.title("Scatterplot for Blood Type vs Medical Condition")
plt.show()

# Medication Type vs Medical Condition
plt.figure(figsize=(8,8))
sns.scatterplot(x=df1["Medication"],y=df1["Medical Condition"])
plt.title("Scatterplot for Medication vs Medical Condition")
plt.show()

# Medical Condition vs Test Results
plt.figure(figsize=(8,8))
sns.scatterplot(x=df1["Medical Condition"],y=df1["Test Results"])
plt.title("Scatterplot for Medication Condition vs Test Results")
plt.show()

#  Medical Condition vs Admission Type
plt.figure(figsize=(8,8))
sns.scatterplot(x=df1["Medical Condition"],y=df1["Admission Type"])
plt.title("Scatterplot for Medication Condition vs Admission Type")
plt.show()

#  Admission Type vs Test Results 
plt.figure(figsize=(8,8))
sns.scatterplot(x=df1["Admission Type"],y=df1["Test Results"])
plt.title("Scatterplot for Admission Type vs Test Results")
plt.show()

# %% [markdown]
# #### Observation:
# - All the scatterplots above shows that there is not corrilation beatween each other and all the data points are evenly spread.
